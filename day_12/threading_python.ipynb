# %% [markdown]
# ## **Threading**

# %%
class Calculator:
    
    def __init__(self,val1,val2):
        self.val1 = val1
        self.val2 = val2        

    def add(self): 
        addition =  self.val1 + self.val2
        return addition

    def sub(self):
        substraction = self.val1 / self.val2
        return substraction

    def mul(self):
        multiply = self.val1 * self.val2
        return multiply

    def power(self):
        exponent = self.val1 ** self.val2
        return exponent
    def log(self,val1,val2=None):
       return np.log(val1)

s = Calculator(0,0)
s.log(2)
# Out:
# np.float64(0.6931471805599453)

# %%
import numpy as np

class Calculator:

    def __init__(self):
        pass

    def add(self, val1, val2):
        return val1 + val2

    def sub(self, val1, val2):
        return val1 - val2

    def mul(self, val1, val2):
        return val1 * val2

    def power(self, val1, val2):
        return val1 ** val2

    def log(self, val1):
        return np.log10(val1)


s = Calculator()

print(s.add(10, 5))
print(s.sub(10, 5))
print(s.mul(10, 5))
print(s.power(2, 3))
print(s.log(2))
# Out:
# 15
# 5
# 50
# 8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 30
#      26 print(s.add(10, 5))
#      27 print(s.sub(10, 5))
#      28 print(s.mul(10, 5))
#      29 print(s.power(2, 3))
# ---> 30 print(s.log(2))
#
# Cell In[82], line 21, in Calculator.log(self, val1)
#      20     def log(self, val1):
# ---> 21         return np.ln(val1)
#
# File c:\Users\My PC\.conda\envs\python_basic\Lib\site-packages\numpy\__init__.py:782, in __getattr__(attr)
#     775 if attr in __expired_attributes__:
#     776     raise AttributeError(
#     777         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     778         f"{__expired_attributes__[attr]}",
#     779         name=None
#     780     )
# --> 782 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'ln'
